# %%
# Mengimpor library
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Mengimpor dataset
dataset_pasut = pd.read_csv('Koef_pasut.csv')

# %%
# Standarisasi data dan feature scalling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_Y = StandardScaler()
sc_X.fit_transform(X)
sc_Y.fit_transform(Y)
# Out:
# array([[ 1.5194775 ],
#        [ 0.75992904],
#        [-0.26942738],
#        [-0.90228428],
#        [-1.10769487]])

# %%
# Menentukan model/Fitting SVR ke dataset
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X,Y)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1141: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
# Visualisasi hasil SVR
plt.scatter(X,Y, color = 'red')
plt.plot(X, regressor.predict(X), color = 'blue')
plt.title('Ketinggian rata-rata gelombang pasang (SVR)')
plt.xlabel('Tahun')
plt.ylabel('Koefisien')
plt.show()

# %%
#Evaluasi model dengan MSE
Y_pred = regressor.predict(X)
MSE = np.mean(np.square(Y - Y_pred))
print('MSE :',MSE)
# Out:
# MSE : 1.655674996919712

# %%
#Evaluasi model dengan RMSE
RMSE = np.sqrt(np.mean(np.square(Y - Y_pred)))
print('RMSE : ', RMSE)
# Out:
# RMSE :  1.2867303512856576

# %%
#export model
import pickle
pickle.dump(regressor, open('modelpasut.pkl','wb'))
